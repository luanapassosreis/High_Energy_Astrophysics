# %% [markdown]
# # Spectrum of the Crab Nebula as seen by LST1
#
# We will use some data shared by the LST1 collaboration. The data can be found at DOI 10.5281/zenodo.11445183

# %% [markdown]
# ## Mandatory imports

# %%
from pathlib import Path

# Check package versions
import numpy as np
import astropy.units as u
from astropy.coordinates import Angle, SkyCoord
from regions import CircleSkyRegion, PointSkyRegion

# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import display
from gammapy.data import DataStore
from gammapy.datasets import (
    Datasets,
    FluxPointsDataset,
    SpectrumDataset,
    SpectrumDatasetOnOff,
)
from gammapy.estimators import FluxPointsEstimator
from gammapy.estimators.utils import resample_energy_edges
from gammapy.makers import (
    ReflectedRegionsBackgroundMaker,
    SafeMaskMaker,
    SpectrumDatasetMaker,
    WobbleRegionsFinder,
    
)
from gammapy.maps import MapAxis, RegionGeom, WcsGeom, Map
from gammapy.modeling import Fit
from gammapy.modeling.models import (
    LogParabolaSpectralModel,
    SkyModel,
    create_crab_spectral_model,
    PowerLawSpectralModel
)
from gammapy.visualization import plot_spectrum_datasets_off_regions

# %% [markdown]
# ## Load the data

# %%
#path_LST_data = "/Users/atreyeesinha/Desktop/LST1/"
path_LST_data = "../LST1-DL3-data"

# %%
datastore = DataStore.from_dir(path_LST_data)

# %%
datastore.hdu_table
# Out:
# <HDUIndexTable length=48>
# OBS_ID HDU_TYPE HDU_CLASS  ...      HDU_NAME        SIZE
# int64   bytes8   bytes10   ...      bytes17        int64
# ------ -------- ---------- ... ----------------- ---------
#   7253   events     events ...            EVENTS 148884480
#   7253      gti        gti ...               GTI 148884480
#   7253 pointing   pointing ...          POINTING 148884480
#   7253     aeff    aeff_2d ...    EFFECTIVE AREA 148884480
#   7253    edisp   edisp_2d ... ENERGY DISPERSION 148884480
#   7253  rad_max rad_max_2d ...           RAD_MAX 148884480
#    ...      ...        ... ...               ...       ...
#   7276  rad_max rad_max_2d ...           RAD_MAX  35602560
#   7277   events     events ...            EVENTS  88323840
#   7277      gti        gti ...               GTI  88323840
#   7277 pointing   pointing ...          POINTING  88323840
#   7277     aeff    aeff_2d ...    EFFECTIVE AREA  88323840
#   7277    edisp   edisp_2d ... ENERGY DISPERSION  88323840
#   7277  rad_max rad_max_2d ...           RAD_MAX  88323840

# %%
datastore.obs_table
# Out:
# <ObservationTable length=8>
# OBS_ID  DATE-OBS    TIME-OBS    DATE-END  ... OBS_MODE N_TELS TELLIST INSTRUME
#                                           ...
# int64   bytes10     bytes12     bytes10   ...  bytes8  int64   bytes5  bytes5
# ------ ---------- ------------ ---------- ... -------- ------ ------- --------
#   7253 2022-03-04 20:40:32.241 2022-03-04 ... POINTING      1   LST-1    LST-1
#   7254 2022-03-04 21:05:30.240 2022-03-04 ... POINTING      1   LST-1    LST-1
#   7255 2022-03-04 21:36:06.784 2022-03-04 ... POINTING      1   LST-1    LST-1
#   7256 2022-03-04 21:53:11.638 2022-03-04 ... POINTING      1   LST-1    LST-1
#   7274 2022-03-05 20:53:16.930 2022-03-05 ... POINTING      1   LST-1    LST-1
#   7275 2022-03-05 21:38:18.716 2022-03-05 ... POINTING      1   LST-1    LST-1
#   7276 2022-03-05 21:59:37.867 2022-03-05 ... POINTING      1   LST-1    LST-1
#   7277 2022-03-05 22:09:31.561 2022-03-05 ... POINTING      1   LST-1    LST-1

# %% [markdown]
# We can see that these are observations of the Crab Nebula in Wobble mode

# %%
# observations = datastore.get_observations()

# %%
observations = datastore.get_observations(required_irf="point-like")

# %%
print(observations)
# Out:
# Observations
# Number of observations: 8
# Observation
#
# 	obs id            : 7253
#  	tstart            : 59642.86
# 	tstop             : 59642.88
# 	duration          : 1206.13 s
# 	pointing (icrs)   : 84.0 deg, 22.3 deg
#
# 	deadtime fraction : 6.4%
# Observation
#
# 	obs id            : 7254
#  	tstart            : 59642.88
# 	tstop             : 59642.89
# 	duration          : 1207.16 s
# 	pointing (icrs)   : 83.3 deg, 21.8 deg
#
# 	deadtime fraction : 6.2%
# Observation
#
# 	obs id            : 7255
#  	tstart            : 59642.90
# 	tstop             : 59642.91
# 	duration          : 950.20 s
# 	pointing (icrs)   : 83.3 deg, 21.8 deg
#
# 	deadtime fraction : 6.0%
# Observation
#
# 	obs id            : 7256
#  	tstart            : 59642.91
# 	tstop             : 59642.92
# 	duration          : 486.66 s
# 	pointing (icrs)   : 84.0 deg, 22.3 deg
#
# 	deadtime fraction : 5.8%
# Observation
#
# 	obs id            : 7274
#  	tstart            : 59643.87
# 	tstop             : 59643.88
# 	duration          : 812.21 s
# 	pointing (icrs)   : 84.0 deg, 22.3 deg
#
# 	deadtime fraction : 6.4%
# Observation
#
# 	obs id            : 7275
#  	tstart            : 59643.90
# 	tstop             : 59643.92
# 	duration          : 1204.38 s
# 	pointing (icrs)   : 83.3 deg, 21.8 deg
#
# 	deadtime fraction : 6.0%
# Observation
#
# 	obs id            : 7276
#  	tstart            : 59643.92
# 	tstop             : 59643.92
# 	duration          : 405.96 s
# 	pointing (icrs)   : 84.0 deg, 22.2 deg
#
# 	deadtime fraction : 5.7%
# Observation
#
# 	obs id            : 7277
#  	tstart            : 59643.92
# 	tstop             : 59643.93
# 	duration          : 931.77 s
# 	pointing (icrs)   : 84.0 deg, 22.3 deg
#
# 	deadtime fraction : 5.3%

# %% [markdown]
# ## Exercise:
# 1. Compute the total observation time and the total livetime
# 2. Peek into the observations for a quick look
# 3. Peek into the irfs for a quick look
# 4. At what energy does the aeff fall below 10% of its maximum value?

# %%
observations[0].events.peek()

# %%
observations[0].aeff.evaluate(energy_true=[[1,10]*u.TeV])
# Out:
# <Quantity [[179592.3864711 , 186684.37205142]] m2>

# %%
observations[0].aeff.peek()

# %%
observations[0].edisp.peek()

# %%
observations[0].peek()

# %%
len(observations[0].events.table)
# Out:
# 1691140

# %% [markdown]
# ## Create Spectra

# %%
target_position = SkyCoord(ra=83.63, dec=22.01, unit="deg", frame="icrs")
on_region = PointSkyRegion(target_position)

# %%
# true and estimated energy axes
energy_axis = MapAxis.from_energy_bounds(
    10, 1e5, nbin=10, per_decade=True, unit="GeV", name="energy"
)

## Usually choose twice the number for the true energy bins
energy_axis_true = MapAxis.from_energy_bounds(
    0.1, 1e5, nbin=20, per_decade=True, unit="GeV", name="energy_true"
)

# geometry defining the ON region and SpectrumDataset based on it
geom = RegionGeom.create(region=on_region, axes=[energy_axis])

dataset_empty = SpectrumDataset.create(geom=geom, energy_axis_true=energy_axis_true)

## Extracts off counts in each region
dataset_maker = SpectrumDatasetMaker(
    containment_correction=False, selection=["counts", "exposure", "edisp"]
)

# tell the background maker to use the WobbleRegionsFinder, let us use 2 off
region_finder = WobbleRegionsFinder(n_off_regions=2)
bkg_maker = ReflectedRegionsBackgroundMaker(region_finder=region_finder)

# use the energy threshold specified in the DL3 files
safe_mask_masker = SafeMaskMaker(methods=["aeff-max"], aeff_percent=10)

# %%
# SafeMaskMaker?

# %%
datasets = Datasets()

# create a counts map for visualisation later...
counts = Map.create(skydir=target_position, width=3)

for observation in observations:
    dataset = dataset_maker.run(
        dataset_empty.copy(name=str(observation.obs_id)), observation
    )
    counts.fill_events(observation.events)
    dataset_on_off = bkg_maker.run(dataset, observation)
    dataset_on_off = safe_mask_masker.run(dataset_on_off, observation)
    datasets.append(dataset_on_off)

# %% [markdown]
# ## Exercise:
# - Play with the number of off regions

# %%
#plot
ax = counts.plot(cmap="viridis")
geom.plot_region(ax=ax, kwargs_point={"color": "k", "marker": "*"})
plot_spectrum_datasets_off_regions(ax=ax, datasets=datasets)
plt.show()
# Out:
# /Users/luanareis/opt/anaconda3/envs/gammapy-1.2/lib/python3.10/site-packages/gammapy/visualization/datasets.py:84: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   handle = Patch(**plot_kwargs)

# %%
# Individual
info_table=datasets.info_table()
info_table
# Out:
# <Table length=8>
# name counts  excess      sqrt_ts       ... acceptance acceptance_off  alpha
#                                        ...
# str4 int64  float64      float64       ...  float64      float64     float64
# ---- ------ ------- ------------------ ... ---------- -------------- -------
# 7253  15277   332.5  2.209902805007544 ...       33.0           66.0     0.5
# 7254  17047  1474.0  9.449196553865805 ...       33.0           66.0     0.5
# 7255   9389   720.5  6.205823011054513 ...       32.0           64.0     0.5
# 7256   5074   360.0  4.210804513793268 ...       32.0           64.0     0.5
# 7274  11095   431.5 3.3816564938425824 ...       33.0           66.0     0.5
# 7275  12800  1100.0   8.13656366425411 ...       32.0           64.0     0.5
# 7276   4526   360.0  4.469699078143401 ...       32.0           64.0     0.5
# 7277   6829   642.5   6.52226356563296 ...       31.0           62.0     0.5

# %%
# Cumulative
info_table= datasets.info_table(cumulative=True)
info_table
# Out:
# <Table length=8>
#   name  counts  excess      sqrt_ts       ... acceptance acceptance_off  alpha
#                                           ...
#   str7  int64  float64      float64       ...  float64      float64     float64
# ------- ------ ------- ------------------ ... ---------- -------------- -------
# stacked  15277   332.5  2.209902805007544 ...       33.0           66.0     0.5
# stacked  32324  1806.5  8.335081914483018 ...       33.0           66.0     0.5
# stacked  41713  2527.0  10.27767173945292 ...       33.0           66.0     0.5
# stacked  46787  2887.0 11.090503241445557 ...       33.0           66.0     0.5
# stacked  57882  3318.5 11.446854479990787 ...       33.0           66.0     0.5
# stacked  70682  4418.5 13.813044533997134 ...       33.0           66.0     0.5
# stacked  75208  4778.5 14.486317093419254 ...       33.0           66.0     0.5
# stacked  82037  5421.0 15.746882521049258 ...       33.0           66.0     0.5

# %%
fig, (ax_excess, ax_sqrt_ts) = plt.subplots(figsize=(10, 4), ncols=2, nrows=1)
ax_excess.plot(
    info_table["livetime"].to("h"),
    info_table["excess"],
    marker="o",
    ls="none",
)

ax_excess.set_title("Excess")
ax_excess.set_xlabel("Livetime [h]")
ax_excess.set_ylabel("Excess events")

ax_sqrt_ts.plot(
    info_table["livetime"].to("h"),
    info_table["sqrt_ts"],
    marker="o",
    ls="none",
)

ax_sqrt_ts.set_title("Sqrt(TS)")
ax_sqrt_ts.set_xlabel("Livetime [h]")
ax_sqrt_ts.set_ylabel("Sqrt(TS)")
plt.show()

# %%
for d in datasets:
    
    fig= d.peek()
    plt.plot()

# %%
dataset = datasets[0]

# %%
dataset.mask_safe
# Out:
# <pre>RegionNDMap
#
# 	geom  : RegionGeom
#  	axes  : [&#x27;lon&#x27;, &#x27;lat&#x27;, &#x27;energy&#x27;]
# 	shape : (1, 1, 40)
# 	ndim  : 3
# 	unit  :
# 	dtype : bool
# </pre>

# %% [markdown]
# ## Now Fit
# - We use a simple power law

# %%
e_min = 80 * u.GeV
e_max = 20 * u.TeV

for dataset in datasets:
    dataset.mask_fit = dataset.counts.geom.energy_mask(e_min, e_max)

spectral_model = PowerLawSpectralModel()
model = SkyModel(spectral_model=spectral_model, name="crab")

datasets.models = [model]

fit = Fit()
result = fit.run(datasets=datasets)

# we make a copy here to compare it later
best_fit_model = model.copy()

# %%
dataset.mask_fit
# Out:
# <pre>RegionNDMap
#
# 	geom  : RegionGeom
#  	axes  : [&#x27;lon&#x27;, &#x27;lat&#x27;, &#x27;energy&#x27;]
# 	shape : (1, 1, 40)
# 	ndim  : 3
# 	unit  :
# 	dtype : bool
# </pre>

# %%
model.parameters.to_table()
# Out:
# <Table length=3>
# type    name     value         unit      ... frozen is_norm link prior
# str1    str9    float64       str14      ...  bool    bool  str1  str1
# ---- --------- ---------- -------------- ... ------ ------- ---- -----
#          index 2.3900e+00                ...  False   False
#      amplitude 3.8272e-11 TeV-1 s-1 cm-2 ...  False    True
#      reference 1.0000e+00            TeV ...   True   False

# %%
l0 = datasets.stat_sum()
print(l0)
# Out:
# 208.88281811216004

# %%
## Binned analysis - lost the photon data
## Choose edges coherent to your energy dataset

## selection_optional="all" == Upper Limits, likelihood and many aspects, it takes longer

# %%
energy_edges=MapAxis.from_energy_bounds(e_min, e_max, nbin=5, per_decade=True).edges
fpe = FluxPointsEstimator(
    energy_edges=energy_edges, source="crab", selection_optional="all"
)
flux_points = fpe.run(datasets=datasets)

# %%
fig, ax = plt.subplots()
sed_type="e2dnde"
flux_points.plot(ax=ax, sed_type=sed_type, color="darkorange")
flux_points.plot_ts_profiles(ax=ax, sed_type=sed_type)
model.spectral_model.plot(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type)
model.spectral_model.plot_error(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type)
plt.show()

# %%
flux_points.meta
# Out:
# {'n_sigma': 1,
#  'n_sigma_ul': 2,
#  'sed_type_init': 'likelihood',
#  'SED_TYPE': 'likelihood'}

# %% [markdown]
# ## Use another model

# %%
spectral2 = LogParabolaSpectralModel()
spectral2.amplitude.value = 4e-11
spectral2.reference.value =  1.0

# %%
model_crab = SkyModel(spectral_model=spectral2, name="crab-lp")
model_crab.parameters.to_table()
# Out:
# <Table length=4>
# type    name     value         unit      ... frozen is_norm link prior
# str1    str9    float64       str14      ...  bool    bool  str1  str1
# ---- --------- ---------- -------------- ... ------ ------- ---- -----
#      amplitude 4.0000e-11 TeV-1 s-1 cm-2 ...  False    True
#      reference 1.0000e+00            TeV ...   True   False
#          alpha 2.0000e+00                ...  False   False
#           beta 1.0000e+00                ...  False   False

# %%
datasets.models = model_crab

# %%
result2 = fit.run(datasets)

# %%
result2.parameters.to_table()
# Out:
# <Table length=4>
# type    name     value         unit      ... frozen is_norm link prior
# str1    str9    float64       str14      ...  bool    bool  str1  str1
# ---- --------- ---------- -------------- ... ------ ------- ---- -----
#      amplitude 4.2585e-11 TeV-1 s-1 cm-2 ...  False    True
#      reference 1.0000e+00            TeV ...   True   False
#          alpha 2.4912e+00                ...  False   False
#           beta 1.4169e-01                ...  False   False

# %%
l1 = datasets.stat_sum()
print(l1)
# Out:
# 177.2490603548799

# %% [markdown]
# We can see there is a significant change in the likelihood.
# Since we are comparing nested models, we can directly do a likelihood ratio test

# %%
del_TS = l0 - l1
del_TS
# Out:
# 31.633757757280137

# %%
from gammapy.stats.utils import ts_to_sigma

# %%
## in a PowerLaw, 1 freedom degree, to a LogParabola, we gain 1 more

# ts_to_sigma?

# %%
ts_to_sigma(del_TS)
# Out:
# 5.6243895453000174

# %%
# FluxPointsEstimator?

# %%
fpe2 = FluxPointsEstimator(
    energy_edges=energy_edges, source="crab-lp", selection_optional="all"
)
flux_points2 = fpe2.run(datasets=datasets)

# %%
fig, ax = plt.subplots()
sed_type="e2dnde" # does not divide by the bin width
# sed_type="flux"
flux_points.plot(ax=ax, sed_type=sed_type, color="darkorange")
flux_points2.plot(ax=ax, sed_type=sed_type, color="blue", alpha=0.5)
model.spectral_model.plot(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type, color="orange")
model.spectral_model.plot_error(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type, facecolor="orange")

model_crab.spectral_model.plot(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type, color="blue")
model_crab.spectral_model.plot_error(ax=ax, energy_bounds=(e_min, e_max), sed_type=sed_type, facecolor="blue")
# Out:
# <Axes: xlabel='Energy [$\\mathrm{GeV}$]', ylabel='e2dnde [$\\mathrm{erg\\,s^{-1}\\,cm^{-2}}$]'>
